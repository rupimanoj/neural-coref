# %%
import pandas as pd
import spacy
import pprint as pprint
import numpy as np
import os
import random
import torch
import math
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
PROCESSED_DATA_DIR = "processed_data"
MODEL_NAME = "BERT_Attention"
model = BertModel.from_pretrained('bert-base-uncased').to(device) 
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
nlp = spacy.load('en')

# %%
def get_bert_embeddings(passage_text):
    passage_text_processed = nlp(passage_text)
    passage_with_separators = ' '.join(['[CLS]'] + [sent.text + ' [SEP]' for sent in passage_text_processed.sents])
    passage_with_separators_tokenized = tokenizer.tokenize(passage_with_separators)    
    model.eval()
    indexed_tokens = tokenizer.convert_tokens_to_ids(passage_with_separators_tokenized)
    tokens_tensor = torch.tensor([indexed_tokens]).to(device)

    with torch.no_grad():
        encoded_layers, _ = model(tokens_tensor)

    indices = [i for i, w in enumerate(passage_with_separators_tokenized) if (w not in ['[CLS]', '[SEP]'])]
    nonseparator_tokens = [w for i, w in enumerate(passage_with_separators_tokenized) if (w not in ['[CLS]', '[SEP]'])]
    nonseparators = torch.squeeze(encoded_layers[-1])[indices][:]

    attn_vectors_per_word = []
    encountered_words = []
    i = 0
    carry_over = None
    had_carry_over = False
    
    for w_i, word in enumerate(passage_text_processed):
        word = word.text.lower()
        first_attention_vector = nonseparators[i]
        current_word = ''
        if word == ' ':
            attn_vectors_per_word.append(first_attention_vector)
            continue
        if carry_over:
            current_word = carry_over
            carry_over = None
        while current_word[:len(word)] != word:
            current_token = nonseparator_tokens[i]
            current_word += (current_token if (current_token[:2] != '##') else current_token[2:])
            i += 1
        encountered_words.append(current_word)
        if not had_carry_over:
            attn_vectors_per_word.append(first_attention_vector)
        else:
            had_carry_over = False
        if len(current_word) > len(word):
            attn_vectors_per_word.append(first_attention_vector)
            carry_over = current_word[len(word):]
            had_carry_over = True
    output = torch.stack(attn_vectors_per_word)
    assert len([word for word in passage_text_processed]) == len(attn_vectors_per_word)
    return output

# %%
train_passages = np.load("processed_data/train_passage_list.npy")

# %%
train_embeddings = []
for i,passage in enumerate(train_passages):
    print("processing doc", i)
    embeddings = get_bert_embeddings(str(passage))
    train_embeddings.append(embeddings)
# Out:
# processing doc 0
# processing doc 1
# processing doc 2
# processing doc 3
# processing doc 4
# processing doc 5
# processing doc 6
# processing doc 7
# processing doc 8
# processing doc 9
# processing doc 10
# processing doc 11
# processing doc 12
# processing doc 13
# processing doc 14
# processing doc 15
# processing doc 16
# processing doc 17
# processing doc 18
# processing doc 19
# processing doc 20
# processing doc 21
# processing doc 22
# processing doc 23
# processing doc 24
# processing doc 25
# processing doc 26
# processing doc 27
# processing doc 28
# processing doc 29
# processing doc 30
# processing doc 31
# processing doc 32
# processing doc 33
# processing doc 34
# processing doc 35
# processing doc 36
# processing doc 37
# processing doc 38
# processing doc 39
# processing doc 40
# processing doc 41
# processing doc 42
# processing doc 43
# processing doc 44
# processing doc 45
# processing doc 46
# processing doc 47
# processing doc 48
# processing doc 49
# processing doc 50
# processing doc 51
# processing doc 52
# processing doc 53
# processing doc 54
# processing doc 55
# processing doc 56
# processing doc 57
# processing doc 58
# processing doc 59
# processing doc 60
# processing doc 61
# processing doc 62
# processing doc 63
# processing doc 64
# processing doc 65
# processing doc 66
# processing doc 67
# processing doc 68
# processing doc 69
# processing doc 70
# processing doc 71
# processing doc 72
# processing doc 73
# processing doc 74
# processing doc 75
# processing doc 76
# processing doc 77
# processing doc 78
# processing doc 79
# processing doc 80
# processing doc 81
# processing doc 82
# processing doc 83
# processing doc 84
# processing doc 85
# processing doc 86
# processing doc 87
# processing doc 88
# processing doc 89
# processing doc 90
# processing doc 91
# processing doc 92
# processing doc 93
# processing doc 94
# processing doc 95
# processing doc 96
# processing doc 97
# processing doc 98
# processing doc 99
# processing doc 100
# processing doc 101
# processing doc 102
# processing doc 103
# processing doc 104
# processing doc 105
# processing doc 106
# processing doc 107
# processing doc 108
# processing doc 109
# processing doc 110
# processing doc 111
# processing doc 112
# processing doc 113
# processing doc 114
# processing doc 115
# processing doc 116
# processing doc 117
# processing doc 118
# processing doc 119
# processing doc 120
# processing doc 121
# processing doc 122
# processing doc 123
# processing doc 124
# processing doc 125
# processing doc 126
# processing doc 127
# processing doc 128
# processing doc 129
# processing doc 130
# processing doc 131
# processing doc 132
# processing doc 133
# processing doc 134
# processing doc 135
# processing doc 136
# processing doc 137
# processing doc 138
# processing doc 139
# processing doc 140
# processing doc 141
# processing doc 142
# processing doc 143
# processing doc 144
# processing doc 145
# processing doc 146
# processing doc 147
# processing doc 148
# processing doc 149
# processing doc 150
# processing doc 151
# processing doc 152
# processing doc 153
# processing doc 154
# processing doc 155
# processing doc 156
# processing doc 157
# processing doc 158
# processing doc 159
# processing doc 160
# processing doc 161
# processing doc 162
# processing doc 163
# processing doc 164
# processing doc 165
# processing doc 166
# processing doc 167
# processing doc 168
# processing doc 169
# processing doc 170
# processing doc 171
# processing doc 172
# processing doc 173
# processing doc 174
# processing doc 175
# processing doc 176
# processing doc 177
# processing doc 178
# processing doc 179
# processing doc 180
# processing doc 181
# processing doc 182
# processing doc 183
# processing doc 184
# processing doc 185
# processing doc 186
# processing doc 187
# processing doc 188
# processing doc 189
# processing doc 190
# processing doc 191
# processing doc 192
# processing doc 193
# processing doc 194
# processing doc 195
# processing doc 196
# processing doc 197
# processing doc 198
# processing doc 199
# processing doc 200
# processing doc 201
# processing doc 202
# processing doc 203
# processing doc 204
# processing doc 205
# processing doc 206
# processing doc 207
# processing doc 208
# processing doc 209
# processing doc 210
# processing doc 211
# processing doc 212
# processing doc 213
# processing doc 214
# processing doc 215
# processing doc 216
# processing doc 217
# processing doc 218
# processing doc 219
# processing doc 220
# processing doc 221
# processing doc 222
# processing doc 223
# processing doc 224
# processing doc 225
# processing doc 226
# processing doc 227
# processing doc 228
# processing doc 229
# processing doc 230
# processing doc 231
# processing doc 232
# processing doc 233
# processing doc 234
# processing doc 235
# processing doc 236
# processing doc 237
# processing doc 238
# processing doc 239
# processing doc 240
# processing doc 241
# processing doc 242
# processing doc 243
# processing doc 244
# processing doc 245
# processing doc 246
# processing doc 247
# processing doc 248
# processing doc 249
# processing doc 250
# processing doc 251
# processing doc 252
# processing doc 253
# processing doc 254
# processing doc 255
# processing doc 256
# processing doc 257
# processing doc 258
# processing doc 259
# processing doc 260
# processing doc 261
# processing doc 262
# processing doc 263
# processing doc 264
# processing doc 265
# processing doc 266
# processing doc 267
# processing doc 268
# processing doc 269
# processing doc 270
# processing doc 271
# processing doc 272
# processing doc 273
# processing doc 274
# processing doc 275
# processing doc 276
# processing doc 277
# processing doc 278
# processing doc 279
# processing doc 280
# processing doc 281
# processing doc 282
# processing doc 283
# processing doc 284
# processing doc 285
# processing doc 286
# processing doc 287
# processing doc 288
# processing doc 289
# processing doc 290
# processing doc 291
# processing doc 292
# processing doc 293
# processing doc 294
# processing doc 295
# processing doc 296
# processing doc 297
# processing doc 298
# processing doc 299
# processing doc 300
# processing doc 301
# processing doc 302
# processing doc 303
# processing doc 304
# processing doc 305
# processing doc 306
# processing doc 307
# processing doc 308
# processing doc 309
# processing doc 310
# processing doc 311
# processing doc 312
# processing doc 313
# processing doc 314
# processing doc 315
# processing doc 316
# processing doc 317
# processing doc 318
# processing doc 319
# processing doc 320
# processing doc 321
# processing doc 322
# processing doc 323
# processing doc 324
# processing doc 325
# processing doc 326
# processing doc 327
# processing doc 328
# processing doc 329
# processing doc 330
# processing doc 331
# processing doc 332
# processing doc 333
# processing doc 334
# processing doc 335
# processing doc 336
# processing doc 337
# processing doc 338
# processing doc 339
# processing doc 340
# processing doc 341
# processing doc 342
# processing doc 343
# processing doc 344
# processing doc 345
# processing doc 346
# processing doc 347
# processing doc 348
# processing doc 349
# processing doc 350
# processing doc 351
# processing doc 352
# processing doc 353
# processing doc 354
# processing doc 355
# processing doc 356
# processing doc 357
# processing doc 358
# processing doc 359
# processing doc 360
# processing doc 361
# processing doc 362
# processing doc 363
# processing doc 364
# processing doc 365
# processing doc 366
# processing doc 367
# processing doc 368
# processing doc 369
# processing doc 370
# processing doc 371
# processing doc 372
# processing doc 373
# processing doc 374
# processing doc 375
# processing doc 376
# processing doc 377
# processing doc 378
# processing doc 379
# processing doc 380
# processing doc 381
# processing doc 382
# processing doc 383
# processing doc 384
# processing doc 385
# processing doc 386
# processing doc 387
# processing doc 388
# processing doc 389
# processing doc 390
# processing doc 391
# processing doc 392
# processing doc 393
# processing doc 394
# processing doc 395
# processing doc 396
# processing doc 397
# processing doc 398
# processing doc 399
# processing doc 400
# processing doc 401
# processing doc 402
# processing doc 403
# processing doc 404
# processing doc 405
# processing doc 406
# processing doc 407
# processing doc 408
# processing doc 409
# processing doc 410
# processing doc 411
# processing doc 412
# processing doc 413
# processing doc 414
# processing doc 415
# processing doc 416
# processing doc 417
# processing doc 418
# processing doc 419
# processing doc 420
# processing doc 421
# processing doc 422
# processing doc 423
# processing doc 424
# processing doc 425
# processing doc 426
# processing doc 427
# processing doc 428
# processing doc 429
# processing doc 430
# processing doc 431
# processing doc 432
# processing doc 433
# processing doc 434
# processing doc 435
# processing doc 436
# processing doc 437
# processing doc 438
# processing doc 439
# processing doc 440
# processing doc 441
# processing doc 442
# processing doc 443
# processing doc 444
# processing doc 445
# processing doc 446
# processing doc 447
# processing doc 448
# processing doc 449
# processing doc 450
# processing doc 451
# processing doc 452
# processing doc 453
# processing doc 454
# processing doc 455
# processing doc 456
# processing doc 457
# processing doc 458
# processing doc 459
# processing doc 460
# processing doc 461
# processing doc 462
# processing doc 463
# processing doc 464
# processing doc 465
# processing doc 466
# processing doc 467
# processing doc 468
# processing doc 469
# processing doc 470
# processing doc 471
# processing doc 472
# processing doc 473
# processing doc 474
# processing doc 475
# processing doc 476
# processing doc 477
# processing doc 478
# processing doc 479
# processing doc 480
# processing doc 481
# processing doc 482
# processing doc 483
# processing doc 484
# processing doc 485
# processing doc 486
# processing doc 487
# processing doc 488
# processing doc 489
# processing doc 490
# processing doc 491
# processing doc 492
# processing doc 493
# processing doc 494
# processing doc 495
# processing doc 496
# processing doc 497
# processing doc 498
# processing doc 499
# processing doc 500
# processing doc 501
# processing doc 502
# processing doc 503
# processing doc 504
# processing doc 505
# processing doc 506
# processing doc 507
# processing doc 508
# processing doc 509
# processing doc 510
# processing doc 511
# processing doc 512
# processing doc 513
# processing doc 514
# processing doc 515
# processing doc 516
# processing doc 517
# processing doc 518
# processing doc 519
# processing doc 520
# processing doc 521
# processing doc 522
# processing doc 523
# processing doc 524
# processing doc 525
# processing doc 526
# processing doc 527
# processing doc 528
# processing doc 529
# processing doc 530
# processing doc 531
# processing doc 532
# processing doc 533
# processing doc 534
# processing doc 535
# processing doc 536
# processing doc 537
# processing doc 538
# processing doc 539
# processing doc 540
# processing doc 541
# processing doc 542
# processing doc 543
# processing doc 544
# processing doc 545
# processing doc 546
# processing doc 547
# processing doc 548
# processing doc 549
# processing doc 550
# processing doc 551
# processing doc 552
# processing doc 553
# processing doc 554
# processing doc 555
# processing doc 556
# processing doc 557
# processing doc 558
# processing doc 559
# processing doc 560
# processing doc 561
# processing doc 562
# processing doc 563
# processing doc 564
# processing doc 565
# processing doc 566
# processing doc 567
# processing doc 568
# processing doc 569
# processing doc 570
# processing doc 571
# processing doc 572
# processing doc 573
# processing doc 574
# processing doc 575
# processing doc 576
# processing doc 577
# processing doc 578
# processing doc 579
# processing doc 580
# processing doc 581
# processing doc 582
# processing doc 583
# processing doc 584
# processing doc 585
# processing doc 586
# processing doc 587
# processing doc 588
# processing doc 589
# processing doc 590
# processing doc 591
# processing doc 592
# processing doc 593
# processing doc 594
# processing doc 595
# processing doc 596
# processing doc 597
# processing doc 598
# processing doc 599
# processing doc 600
# processing doc 601
# processing doc 602
# processing doc 603
# processing doc 604
# processing doc 605
# processing doc 606
# processing doc 607
# processing doc 608
# processing doc 609
# processing doc 610
# processing doc 611
# processing doc 612
# processing doc 613
# processing doc 614
# processing doc 615
# processing doc 616
# processing doc 617
# processing doc 618
# processing doc 619
# processing doc 620
# processing doc 621
# processing doc 622
# processing doc 623
# processing doc 624
# processing doc 625
# processing doc 626
# processing doc 627
# processing doc 628
# processing doc 629
# processing doc 630
# processing doc 631
# processing doc 632
# processing doc 633
# processing doc 634
# processing doc 635
# processing doc 636
# processing doc 637
# processing doc 638
# processing doc 639
# processing doc 640
# processing doc 641
# processing doc 642
# processing doc 643
# processing doc 644
# processing doc 645
# processing doc 646
# processing doc 647
# processing doc 648
# processing doc 649
# processing doc 650
# processing doc 651
# processing doc 652
# processing doc 653
# processing doc 654
# processing doc 655
# processing doc 656
# processing doc 657
# processing doc 658
# processing doc 659
# processing doc 660
# processing doc 661
# processing doc 662
# processing doc 663
# processing doc 664
# processing doc 665
# processing doc 666
# processing doc 667
# processing doc 668
# processing doc 669
# processing doc 670
# processing doc 671
# processing doc 672
# processing doc 673
# processing doc 674
# processing doc 675
# processing doc 676
# processing doc 677
# processing doc 678
# processing doc 679
# processing doc 680
# processing doc 681
# processing doc 682
# processing doc 683
# processing doc 684
# processing doc 685
# processing doc 686
# processing doc 687
# processing doc 688
# processing doc 689
# processing doc 690
# processing doc 691
# processing doc 692
# processing doc 693
# processing doc 694
# processing doc 695
# processing doc 696
# processing doc 697
# processing doc 698
# processing doc 699
# processing doc 700
# processing doc 701
# processing doc 702
# processing doc 703
# processing doc 704
# processing doc 705
# processing doc 706
# processing doc 707
# processing doc 708
# processing doc 709
# processing doc 710
# processing doc 711
# processing doc 712
# processing doc 713
# processing doc 714
# processing doc 715
# processing doc 716
# processing doc 717
# processing doc 718
# processing doc 719
# processing doc 720
# processing doc 721
# processing doc 722
# processing doc 723
# processing doc 724
# processing doc 725
# processing doc 726
# processing doc 727
# processing doc 728
# processing doc 729
# processing doc 730
# processing doc 731
# processing doc 732
# processing doc 733
# processing doc 734
# processing doc 735
# processing doc 736
# processing doc 737
# processing doc 738
# processing doc 739
# processing doc 740
# processing doc 741
# processing doc 742
# processing doc 743
# processing doc 744
# processing doc 745
# processing doc 746
# processing doc 747
# processing doc 748
# processing doc 749
# processing doc 750
# processing doc 751
# processing doc 752
# processing doc 753
# processing doc 754
# processing doc 755
# processing doc 756
# processing doc 757
# processing doc 758
# processing doc 759
# processing doc 760
# processing doc 761
# processing doc 762
# processing doc 763
# processing doc 764
# processing doc 765
# processing doc 766
# processing doc 767
# processing doc 768
# processing doc 769
# processing doc 770
# processing doc 771
# processing doc 772
# processing doc 773
# processing doc 774
# processing doc 775
# processing doc 776
# processing doc 777
# processing doc 778
# processing doc 779
# processing doc 780
# processing doc 781
# processing doc 782
# processing doc 783
# processing doc 784
# processing doc 785
# processing doc 786
# processing doc 787
# processing doc 788
# processing doc 789
# processing doc 790
# processing doc 791
# processing doc 792
# processing doc 793
# processing doc 794
# processing doc 795
# processing doc 796
# processing doc 797
# processing doc 798
# processing doc 799
# processing doc 800
# processing doc 801
# processing doc 802
# processing doc 803
# processing doc 804
# processing doc 805
# processing doc 806
# processing doc 807
# processing doc 808
# processing doc 809
# processing doc 810
# processing doc 811
# processing doc 812
# processing doc 813
# processing doc 814
# processing doc 815
# processing doc 816
# processing doc 817
# processing doc 818
# processing doc 819
# processing doc 820
# processing doc 821
# processing doc 822
# processing doc 823
# processing doc 824
# processing doc 825
# processing doc 826
# processing doc 827
# processing doc 828
# processing doc 829
# processing doc 830
# processing doc 831
# processing doc 832
# processing doc 833
# processing doc 834
# processing doc 835
# processing doc 836
# processing doc 837
# processing doc 838
# processing doc 839
# processing doc 840
# processing doc 841
# processing doc 842
# processing doc 843
# processing doc 844
# processing doc 845
# processing doc 846
# processing doc 847
# processing doc 848
# processing doc 849
# processing doc 850
# processing doc 851
# processing doc 852
# processing doc 853
# processing doc 854
# processing doc 855
# processing doc 856
# processing doc 857
# processing doc 858
# processing doc 859
# processing doc 860
# processing doc 861
# processing doc 862
# processing doc 863
# processing doc 864
# processing doc 865
# processing doc 866
# processing doc 867
# processing doc 868
# processing doc 869
# processing doc 870
# processing doc 871
# processing doc 872
# processing doc 873
# processing doc 874
# processing doc 875
# processing doc 876
# processing doc 877
# processing doc 878
# processing doc 879
# processing doc 880
# processing doc 881
# processing doc 882
# processing doc 883
# processing doc 884
# processing doc 885
# processing doc 886
# processing doc 887
# processing doc 888
# processing doc 889
# processing doc 890
# processing doc 891
# processing doc 892
# processing doc 893
# processing doc 894
# processing doc 895
# processing doc 896
# processing doc 897
# processing doc 898
# processing doc 899
# processing doc 900
# processing doc 901
# processing doc 902
# processing doc 903
# processing doc 904
# processing doc 905
# processing doc 906
# processing doc 907
# processing doc 908
# processing doc 909
# processing doc 910
# processing doc 911
# processing doc 912
# processing doc 913
# processing doc 914
# processing doc 915
# processing doc 916
# processing doc 917
# processing doc 918
# processing doc 919
# processing doc 920
# processing doc 921
# processing doc 922
# processing doc 923
# processing doc 924
# processing doc 925
# processing doc 926
# processing doc 927
# processing doc 928
# processing doc 929
# processing doc 930
# processing doc 931
# processing doc 932
# processing doc 933
# processing doc 934
# processing doc 935
# processing doc 936
# processing doc 937
# processing doc 938
# processing doc 939
# processing doc 940
# processing doc 941
# processing doc 942
# processing doc 943
# processing doc 944
# processing doc 945
# processing doc 946
# processing doc 947
# processing doc 948
# processing doc 949
# processing doc 950
# processing doc 951
# processing doc 952
# processing doc 953
# processing doc 954
# processing doc 955
# processing doc 956
# processing doc 957
# processing doc 958
# processing doc 959
# processing doc 960
# processing doc 961
# processing doc 962
# processing doc 963
# processing doc 964
# processing doc 965
# processing doc 966
# processing doc 967
# processing doc 968
# processing doc 969
# processing doc 970
# processing doc 971
# processing doc 972
# processing doc 973
# processing doc 974
# processing doc 975
# processing doc 976
# processing doc 977
# processing doc 978
# processing doc 979
# processing doc 980
# processing doc 981
# processing doc 982
# processing doc 983
# processing doc 984
# processing doc 985
# processing doc 986
# processing doc 987
# processing doc 988
# processing doc 989
# processing doc 990
# processing doc 991
# processing doc 992
# processing doc 993
# processing doc 994
# processing doc 995
# processing doc 996
# processing doc 997
# processing doc 998
# processing doc 999
# processing doc 1000
# processing doc 1001
# processing doc 1002
# processing doc 1003
# processing doc 1004
# processing doc 1005
# processing doc 1006
# processing doc 1007
# processing doc 1008
# processing doc 1009
# processing doc 1010
# processing doc 1011
# processing doc 1012
# processing doc 1013
# processing doc 1014
# processing doc 1015
# processing doc 1016
# processing doc 1017
# processing doc 1018
# processing doc 1019
# processing doc 1020
# processing doc 1021
# processing doc 1022
# processing doc 1023
# processing doc 1024
# processing doc 1025
# processing doc 1026
# processing doc 1027
# processing doc 1028
# processing doc 1029
# processing doc 1030
# processing doc 1031
# processing doc 1032
# processing doc 1033
# processing doc 1034
# processing doc 1035
# processing doc 1036
# processing doc 1037
# processing doc 1038
# processing doc 1039
# processing doc 1040
# processing doc 1041
# processing doc 1042
# processing doc 1043
# processing doc 1044
# processing doc 1045
# processing doc 1046
# processing doc 1047
# processing doc 1048
# processing doc 1049
# processing doc 1050
# processing doc 1051
# processing doc 1052
# processing doc 1053
# processing doc 1054
# processing doc 1055
# processing doc 1056
# processing doc 1057
# processing doc 1058
# processing doc 1059
# processing doc 1060
# processing doc 1061
# processing doc 1062
# processing doc 1063
# processing doc 1064
# processing doc 1065
# processing doc 1066
# processing doc 1067
# processing doc 1068
# processing doc 1069
# processing doc 1070
# processing doc 1071
# processing doc 1072
# processing doc 1073
# processing doc 1074
# processing doc 1075
# processing doc 1076
# processing doc 1077
# processing doc 1078
# processing doc 1079
# processing doc 1080
# processing doc 1081
# processing doc 1082
# processing doc 1083
# processing doc 1084
# processing doc 1085
# processing doc 1086
# processing doc 1087
# processing doc 1088
# processing doc 1089
# processing doc 1090
# processing doc 1091
# processing doc 1092
# processing doc 1093
# processing doc 1094
# processing doc 1095
# processing doc 1096
# processing doc 1097
# processing doc 1098
# processing doc 1099
# processing doc 1100
# processing doc 1101
# processing doc 1102
# processing doc 1103
# processing doc 1104
# processing doc 1105
# processing doc 1106
# processing doc 1107
# processing doc 1108
# processing doc 1109
# processing doc 1110
# processing doc 1111
# processing doc 1112
# processing doc 1113
# processing doc 1114
# processing doc 1115
# processing doc 1116
# processing doc 1117
# processing doc 1118
# processing doc 1119
# processing doc 1120
# processing doc 1121
# processing doc 1122
# processing doc 1123
# processing doc 1124
# processing doc 1125
# processing doc 1126
# processing doc 1127
# processing doc 1128
# processing doc 1129
# processing doc 1130
# processing doc 1131
# processing doc 1132
# processing doc 1133
# processing doc 1134
# processing doc 1135
# processing doc 1136
# processing doc 1137
# processing doc 1138
# processing doc 1139
# processing doc 1140
# processing doc 1141
# processing doc 1142
# processing doc 1143
# processing doc 1144
# processing doc 1145
# processing doc 1146
# processing doc 1147
# processing doc 1148
# processing doc 1149
# processing doc 1150
# processing doc 1151
# processing doc 1152
# processing doc 1153
# processing doc 1154
# processing doc 1155
# processing doc 1156
# processing doc 1157
# processing doc 1158
# processing doc 1159
# processing doc 1160
# processing doc 1161
# processing doc 1162
# processing doc 1163
# processing doc 1164
# processing doc 1165
# processing doc 1166
# processing doc 1167
# processing doc 1168
# processing doc 1169
# processing doc 1170
# processing doc 1171
# processing doc 1172
# processing doc 1173
# processing doc 1174
# processing doc 1175
# processing doc 1176
# processing doc 1177
# processing doc 1178
# processing doc 1179
# processing doc 1180
# processing doc 1181
# processing doc 1182
# processing doc 1183
# processing doc 1184
# processing doc 1185
# processing doc 1186
# processing doc 1187
# processing doc 1188

# %%
test_passages = np.load("processed_data/test_passage_list.npy")

# %%
test_embeddings = []
for i,passage in enumerate(test_passages):
    print("processing doc", i)
    embeddings = get_bert_embeddings(str(passage))
    test_embeddings.append(embeddings)
# Out:
# processing doc 0
# processing doc 1
# processing doc 2
# processing doc 3
# processing doc 4
# processing doc 5
# processing doc 6
# processing doc 7
# processing doc 8
# processing doc 9
# processing doc 10
# processing doc 11
# processing doc 12
# processing doc 13
# processing doc 14
# processing doc 15
# processing doc 16
# processing doc 17
# processing doc 18
# processing doc 19
# processing doc 20
# processing doc 21
# processing doc 22
# processing doc 23
# processing doc 24
# processing doc 25
# processing doc 26
# processing doc 27
# processing doc 28
# processing doc 29
# processing doc 30
# processing doc 31
# processing doc 32
# processing doc 33
# processing doc 34
# processing doc 35
# processing doc 36
# processing doc 37
# processing doc 38
# processing doc 39
# processing doc 40
# processing doc 41
# processing doc 42
# processing doc 43
# processing doc 44
# processing doc 45
# processing doc 46
# processing doc 47
# processing doc 48
# processing doc 49
# processing doc 50
# processing doc 51
# processing doc 52
# processing doc 53
# processing doc 54
# processing doc 55
# processing doc 56
# processing doc 57
# processing doc 58
# processing doc 59
# processing doc 60
# processing doc 61
# processing doc 62
# processing doc 63
# processing doc 64
# processing doc 65
# processing doc 66
# processing doc 67
# processing doc 68
# processing doc 69
# processing doc 70
# processing doc 71
# processing doc 72
# processing doc 73
# processing doc 74
# processing doc 75
# processing doc 76
# processing doc 77
# processing doc 78
# processing doc 79
# processing doc 80
# processing doc 81
# processing doc 82
# processing doc 83
# processing doc 84
# processing doc 85
# processing doc 86
# processing doc 87
# processing doc 88
# processing doc 89
# processing doc 90
# processing doc 91
# processing doc 92
# processing doc 93
# processing doc 94
# processing doc 95
# processing doc 96
# processing doc 97
# processing doc 98
# processing doc 99
# processing doc 100
# processing doc 101
# processing doc 102
# processing doc 103
# processing doc 104
# processing doc 105
# processing doc 106
# processing doc 107
# processing doc 108
# processing doc 109
# processing doc 110
# processing doc 111
# processing doc 112
# processing doc 113
# processing doc 114
# processing doc 115
# processing doc 116
# processing doc 117
# processing doc 118
# processing doc 119
# processing doc 120
# processing doc 121
# processing doc 122
# processing doc 123
# processing doc 124
# processing doc 125
# processing doc 126
# processing doc 127
# processing doc 128
# processing doc 129
# processing doc 130
# processing doc 131
# processing doc 132

# %%
print(len(train_embeddings), len(test_embeddings), len(train_embeddings[0][0]), len(test_embeddings[0][0]))
# Out:
# 1189 133 768 768

# %%
total_positive_pairs = np.load("./processed_data/train_positive_pairs.npy")
total_negative_pairs = np.load("./processed_data/train_negative_pairs.npy")
test_positive_pairs = np.load("./processed_data/test_positive_pairs.npy")
test_negative_pairs = np.load("./processed_data/test_negative_pairs.npy")
train_positive_pairs = total_positive_pairs[0:1000]
train_negative_pairs = total_negative_pairs[0:1000]
valid_positive_pairs = total_positive_pairs[1000:]
valid_negative_pairs = total_negative_pairs[1000:]

# %%
X_train = []
Y_train = []
X_valid = []
Y_valid = []
X_test = []
Y_test = []

# %%
for i, doc_pairs in enumerate(train_positive_pairs):
    for coref_pair in doc_pairs:
        sample = [i, coref_pair[0][0], coref_pair[0][1], coref_pair[1][0], coref_pair[1][1]]
        X_train.append(sample)
        Y_train.append([1])
for i, doc_pairs in enumerate(train_negative_pairs):
    for coref_pair in doc_pairs:
        sample = [i, coref_pair[0][0], coref_pair[0][1], coref_pair[1][0], coref_pair[1][1]]
        X_train.append(sample)
        Y_train.append([0])

# %%
for i, doc_pairs in enumerate(valid_positive_pairs):
    for coref_pair in doc_pairs:
        sample = [i, coref_pair[0][0], coref_pair[0][1], coref_pair[1][0], coref_pair[1][1]]
        X_valid.append(sample)
        Y_valid.append([1])
for i, doc_pairs in enumerate(valid_negative_pairs):
    for coref_pair in doc_pairs:
        sample = [i, coref_pair[0][0], coref_pair[0][1], coref_pair[1][0], coref_pair[1][1]]
        X_valid.append(sample)
        Y_valid.append([0])

# %%
for i, doc_pairs in enumerate(test_positive_pairs):
    for coref_pair in doc_pairs:
        sample = [i, coref_pair[0][0], coref_pair[0][1], coref_pair[1][0], coref_pair[1][1]]
        X_test.append(sample)
        Y_test.append([1])
for i, doc_pairs in enumerate(test_negative_pairs):
    for coref_pair in doc_pairs:
        sample = [i, coref_pair[0][0], coref_pair[0][1], coref_pair[1][0], coref_pair[1][1]]
        X_test.append(sample)
        Y_test.append([0])

# %%
shuffled_idx = list(np.random.permutation(len(X_train)))
X_train = np.array([X_train[i] for i in shuffled_idx])
Y_train = np.array([Y_train[i] for i in shuffled_idx])

# %%
shuffled_idx = list(np.random.permutation(len(X_valid)))
X_valid = np.array([X_train[i] for i in shuffled_idx])
Y_valid = np.array([Y_train[i] for i in shuffled_idx])

# %%
shuffled_idx = list(np.random.permutation(len(X_test)))
X_test = np.array([X_test[i] for i in shuffled_idx])
Y_test = np.array([Y_test[i] for i in shuffled_idx])

# %%
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
def get_featues_from_pairs(X_batch, embeddings):
    batch_embeddings = []
    for x in X_batch:
        doc_id, a_start, a_end, b_start, b_end = x 
        doc_emb = embeddings[doc_id]
        emb_a = torch.sum(doc_emb[a_start:a_end+1], 0)
        emb_b = torch.sum(doc_emb[b_start:b_end+1], 0)
        emb_dot = torch.mul(emb_a, emb_a)
        emb_cat   = torch.cat((emb_a, emb_b), 0)
        emb   = torch.cat((emb_cat, emb_dot), 0)
        batch_embeddings.append(emb)
    return torch.stack(batch_embeddings)

# %%
def confusion(prediction, truth):
    confusion_vector = prediction / truth
    true_positives = torch.sum(confusion_vector == 1).item()
    false_positives = torch.sum(confusion_vector == float('inf')).item()
    true_negatives = torch.sum(torch.isnan(confusion_vector)).item()
    false_negatives = torch.sum(confusion_vector == 0).item()

    return true_positives, false_positives, true_negatives, false_negatives

# %%
def calculate_f1(Y, y_preds):
    y_actuals = torch.tensor(Y).type(torch.float32).to(device)
    y_preds = y_preds.to(device)
    tp, fp, tn, fn = confusion(y_preds, y_actuals)
    precision = tp*1.0/(tp+fp)
    recall   = tp*1.0/(tp+fn)
    f1 = 2.0*precision*recall/(precision+recall)
    return precision, recall, f1

# %%
def train_epoch(model, opt, criterion, batch_size, X_data, Y_data, embeddings, mode="train"):
    
    if(mode == "train"):
        model.train()
    else:
        model.eval()
    
    losses = []
    running_corrects = 0
    shuffled_idx = list(np.random.permutation(len(X_data)))
    minibatch_idxs = np.array_split(shuffled_idx, len(shuffled_idx)/batch_size) 
    ones = 0
    zeros = 0
    y_preds_all = torch.Tensor().to(device)
    y_hats_all = torch.Tensor().to(device)
    for minibatch_ids in minibatch_idxs:
        x_batch_raw = X_data[minibatch_ids]
        x_batch = get_featues_from_pairs(x_batch_raw, embeddings)
        y_batch = torch.tensor(Y_data[minibatch_ids]).type(torch.float32)
        x_batch = Variable(x_batch).to(device)
        y_batch = Variable(y_batch).to(device)
        opt.zero_grad()
        
        if(mode == "train"):
            y_hat = model(x_batch)
        else:
            with torch.no_grad():
                y_hat = model(x_batch)
        
        y_preds = (y_hat > 0.7).type(torch.float32)
        #print((y_hat).size(), (y_batch).size())
        loss = criterion(y_hat.to("cpu"), y_batch.to("cpu"))
        corrects = float(torch.sum(y_preds == y_batch).item())
        running_corrects += corrects
        ones  += torch.sum(y_preds==1).item()
        zeros +=  torch.sum(y_preds==0).item()
        if(mode == "train"):
            loss.backward()
            opt.step()    
        losses.append(loss.item())
        y_preds_all = torch.cat((y_preds_all,y_preds))
        y_hats_all = torch.cat((y_preds_all,y_hat))
    print("ones and zeros", ones, zeros)
    accuracy = running_corrects * 1.0 / len(shuffled_idx)
    avg_loss = sum(losses) * 1.0 / len(losses)
    precision, recall, F1 = calculate_f1(Y_data, y_preds_all)
    return avg_loss, accuracy, precision, recall, F1

# %%
def predict(model, X, embeddings):
    model.eval()
    idxs = range(0, len(X))
    minibatch_idxs = np.array_split(idxs, len(idxs)/batch_size)
    y_preds_all = torch.Tensor().to(device)
    y_hats_all = torch.Tensor().to(device)
    for minibatch_ids in minibatch_idxs:
        x_batch_raw = X[minibatch_ids]
        x_batch = get_featues_from_pairs(x_batch_raw, embeddings)
        x_batch = Variable(x_batch).to(device)
        opt.zero_grad()
        with torch.no_grad():
                y_hats = model(x_batch)
        y_preds = (y_hats > 0.7).type(torch.float32)
        y_preds_all = torch.cat((y_preds_all,y_preds))
        y_hats_all = torch.cat((y_hats_all,y_hats))
    return y_preds_all, y_hats_all

# %%
def evaluate(model, X, Y, embeddings):
    y_preds, y_hats = predict(model, X, embeddings)
    Y = Variable(torch.tensor(Y).type(torch.float32)).to(device)
    corrects = float(torch.sum(y_preds == Y).item())
    accuracy = corrects * 1.0 / Y.size()[0]
    return accuracy,y_preds, y_hats

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(768*3, 512)
        self.relu1 = nn.ReLU()
        self.dout = nn.Dropout(0.4)
        self.fc2 = nn.Linear(512, 64)
        self.relu2 = nn.ReLU()
        self.out = nn.Linear(64, 1)
        #self.out_act = nn.Sigmoid()
        
    def forward(self, input_):
        a1 = self.fc1(input_)
        h1 = self.relu1(a1)
        dout = self.dout(h1)
        a2 = self.fc2(dout)
        h2 = self.relu2(a2)
        a3 = self.out(h2)
        #y = self.out_act(a3)
        return a3

# %%
net = Net().to(device)
net.apply(init_weights)
opt = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))
batch_size = 1024
num_epochs = 20
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([0.2])) #pos_weight=torch.tensor([0.8,1]), pos_weight=torch.tensor([0.8,1])

# %%
train_loss_seq = []
val_loss_seq = []
train_acc_seq = []
val_acc_seq = []
for e in range(num_epochs):
    print("================ EPOCH", e, "/", num_epochs)
    train_loss, train_acc, precision, recall, f1 = train_epoch(net, opt, criterion, batch_size, X_train, Y_train, train_embeddings,"train")
    val_loss, val_acc, precision, recall, f1 = train_epoch(net, opt, criterion, batch_size, X_valid, Y_valid, train_embeddings, "validation")
    train_loss_seq.append(train_loss)
    train_acc_seq.append(train_acc)
    val_loss_seq.append(val_loss)
    val_acc_seq.append(val_acc)
    print("Train loss and accuracy, prf1: ", train_loss, train_acc,precision, recall, f1)
    print("Val loss and accuracy, prf1: ", val_loss, val_acc,precision, recall, f1)
# Out:
# ================ EPOCH 0 / 20
# ones and zeros 664 843070
# ones and zeros 0 697508
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-123-00c66ecd483d> in <module>
#       6     print("================ EPOCH", e, "/", num_epochs)
#       7     train_loss, train_acc, precision, recall, f1 = train_epoch(net, opt, criterion, batch_size, X_train, Y_train, train_embeddings,"train")
# ----> 8     val_loss, val_acc, precision, recall, f1 = train_epoch(net, opt, criterion, batch_size, X_valid, Y_valid, train_embeddings, "validation")
#       9     train_loss_seq.append(train_loss)
#      10     train_acc_seq.append(train_acc)
#
# <ipython-input-117-fe692b862508> in train_epoch(model, opt, criterion, batch_size, X_data, Y_data, embeddings, mode)
#      44     accuracy = running_corrects * 1.0 / len(shuffled_idx)
#      45     avg_loss = sum(losses) * 1.0 / len(losses)
# ---> 46     precision, recall, F1 = calculate_f1(Y_data, y_preds_all)
#      47     return avg_loss, accuracy, precision, recall, F1
#
# <ipython-input-116-57eb1b7235b0> in calculate_f1(Y, y_preds)
#       3     y_preds = y_preds.to(device)
#       4     tp, fp, tn, fn = confusion(y_preds, y_actuals)
# ----> 5     precision = tp*1.0/(tp+fp)
#       6     recall   = tp*1.0/(tp+fn)
#       7     f1 = 2.0*precision*recall/(precision+recall)
#
# ZeroDivisionError: float division by zero

# %%
torch.save(net.state_dict(), "processed_data/second_run.pth")

# %%
model = Net()
model.load_state_dict(torch.load("processed_data/second_run.pth"))
model.to(device)
model.eval()
# Out:
# Net(
#   (fc1): Linear(in_features=2304, out_features=512, bias=True)
#   (relu1): ReLU()
#   (dout): Dropout(p=0.4)
#   (fc2): Linear(in_features=512, out_features=64, bias=True)
#   (relu2): ReLU()
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
accuracy, y_preds, y_hats = evaluate(model, X_test, Y_test, test_embeddings)

# %%
numpy_y_preds = y_preds.view(1, y_preds.size()[0]).to("cpu").numpy()[0].astype(int)
numpy_y_actuals = Y_test.reshape(1, Y_test.shape[0])[0].astype(int)

# %%
from sklearn.metrics import confusion_matrix

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
numpy_y_preds
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
unique_labels(numpy_y_preds)
# Out:
# array([0, 1])

# %%
classes = np.array([0,1])
plot_confusion_matrix(numpy_y_actuals, numpy_y_preds, classes)
# Out:
# Confusion matrix, without normalization
# [[46262  1238]
#  [ 2982  6555]]

# %% [markdown]
# ### Clustering
